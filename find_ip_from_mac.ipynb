# %%
import subprocess

# %%
# Ping all hosts on the network
for i in range(1, 255):
    subprocess.run(("fping -t50", "192.168.1.%d" %i))

# %%
# example output 
output = '? (192.168.1.48) at 94:65:9c:10:f5:d1 [ether] on wlan0'
output[output.find("(")+1:output.find(")")]
# Out:
# '192.168.1.48'

# %%
def find_ip(mac_address):
    # Get the list of IP and MAC address in the network
    list_ip = subprocess.check_output(("arp", "-a"))
    list_ip = list_ip.decode("utf-8")
    list_ip = list_ip.splitlines()
    # Find IP of camera
    for line in list_ip:
        if line.find(mac_address) != -1:
            # extract the ip address
            ip_address = line[line.find("(")+1:line.find(")")]
    return ip_address

# %%
# Raspberry Pi 
pi_address = "b8-27-eb-c3-cc-5a"

# %%
find_ip(pi_address)
# Out:
# '192.168.1.51'

# %%
# Camera
cam_address = "50-8f-4c-58-71-ff"

# %%
find_ip(cam_address)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-82-f5cabab1dc4e> in <module>
# ----> 1 find_ip(cam_address)
#
# <ipython-input-56-0501a18d89ee> in find_ip(mac_address)
#       9             # extract the ip address
#      10             ip_address = line[2:14]
# ---> 11     return ip_address
#      12
#      13
#
# UnboundLocalError: local variable 'ip_address' referenced before assignment

# %%
# Get all ip adrress of devices layer
try:
    find_ip(cam_address)
except:
    print("Can't find ip address from the network!")
# Out:
# Can't find ip address from the network!
