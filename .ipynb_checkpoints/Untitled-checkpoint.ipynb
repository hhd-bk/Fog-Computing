# %%
import subprocess
import requests
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras

# %%
def find_ip():
    # Get the list of IP and MAC address in the network
    list_ip = subprocess.check_output(("arp", "-a"))
    list_ip = list_ip.decode("utf-8")
    list_ip = list_ip.splitlines()
    # My camera MAC address
    mac_add = "50-8f-4c-58-71-ff"
    # Find IP of camera
    for line in list_ip:
        if line.find(mac_add) != -1:
            # extract the ip address
            ip_address = line[2:14]
    return ip_address

# %%
def take_img(ip_address):
    url = "http://"+ ip_address + ":8080/shot.jpg"
    response = requests.get(url)
    # Decode to get image from byte value
    img = np.array(bytearray(response.content), dtype=np.uint8)
    img = cv2.imdecode(img, 1)
    # Resize to feed to the network
    img = cv2.resize(img, (50, 50))
    img = np.array([img])
    return img

# %%
model = keras.models.load_model('model\\model_1.h5')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 46, 46, 32)        2432
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 9, 9, 32)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2592)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               1327616
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 1,331,074
# Trainable params: 1,331,074
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.imshow(take_img(find_ip())[0])
plt.title('my picture')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b86d917437c1> in <module>
# ----> 1 plt.imshow(take_img(find_ip())[0])
#       2 plt.title('my picture')
#
# <ipython-input-25-19e8e0f1dd17> in take_img(ip_address)
#       4     # Decode to get image from byte value
#       5     img = np.array(bytearray(response.content), dtype=np.uint32)
# ----> 6     img = cv2.imdecode(img, 1)
#       7     # Resize to feed to the network
#       8     img = cv2.resize(img, (50, 50))
#
# TypeError: Expected cv::UMat for argument 'buf'

# %%
model.predict([take_img(find_ip())])
# Out:
# array([[0., 1.]], dtype=float32)
