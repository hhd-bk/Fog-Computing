# %%
# Import everything we need

# %%
# find ip from mac

# %%
# take picture

# %%
url = 'http://192.168.1.28:8080/shot.jpg'
response = requests.get(url)

# %%
img_arr = np.array(bytearray(response.content), dtype=np.uint8)

# %%
img = cv2.imdecode(img_arr, -1)

# %%
plt.imshow(img)
plt.title('my picture')
plt.show()

# %%
# take predict using the model and output
# fire - [1 0] - 410 images
# nothing - [0 1] - 539 images
